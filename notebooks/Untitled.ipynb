# %%
# %load_ext autoreload
# %autoreload 2

import sys, os
import numpy as np
import matplotlib.pyplot as plt
fs = 12
plt.rc('font', family='serif')
plt.rc('font', size=fs)
plt.rc('facecolor', )
import pandas as pd
import scipy.io as sio

# met mast functions and utilities
sys.path.append('../')
import met_funcs as MET
import vis as vis
import utils as utils

# %%
tmp = MET.load_met_data([dpath])

# %%
tmp['Wind Shear (38_ 122 m)'].plot()

# %%
spd = tmp['Speed (cup_ 87 m)']
shr = tmp['Wind Shear (38_ 122 m)']

# %%
alpha_pos = np.load('../../data/pos_alpha_limit.npy')
alpha_neg = np.load('../../data/neg_alpha_limit.npy')
alpha_reference_velocity = np.load('../../data/alpha_reference_velocity.npy')

# %%
plt.plot(alpha_reference_velocity, alpha_pos, color='C1')
plt.plot(alpha_reference_velocity, alpha_neg, color='C2')
plt.scatter(spd, shr)
