# %%
import pandas as pd
df = pd.read_csv('../../data/2013-2016_filtered_data.csv', low_memory=False)

# %%
rows, columns = df.shape

# %% [markdown]
# #

# %%
df.shape
# Out:
# (171726, 239)

# %%
df.head()
# Out:
#    Unnamed: 0 Unnamed: 1         Unnamed: 2 Unnamed: 3  \
# 0          --        NaN                NaN        NaN
# 1  mm/dd/yyyy       Time    mm/dd/yyyy Time   UTC HOUR
# 2      1/1/13   12:00 AM  1/1/2013 12:00 AM          0
# 3      1/1/13   12:10 AM  1/1/2013 12:10 AM          0
# 4      1/1/13   12:20 AM  1/1/2013 12:20 AM          0
#
#         Speed (cup_ 130 m)      Speed (cup_ 130 m) QC  Ti (cup_ 130 m)  \
# 0  Wind_Speed_Cup_130m.val  Wind_Speed_Cup_130m.flags  Ti_Cup_130m.val
# 1                      m/s    pass/flag/fail [1/0/-1]                %
# 2                 0.860275                          0        13.335154
# 3                 0.730182                          0        20.240985
# 4                 0.098562                          0       154.370441
#
#         Ti (cup_ 130 m) QC            Direction (Vane_ 130 m)  \
# 0        Ti_Cup_130m.flags  Wind_Direction_Vane_130m_mean.val
# 1  pass/flag/fail [1/0/-1]                            degrees
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3',
#        'Speed (cup_ 130 m)', 'Speed (cup_ 130 m) QC', 'Ti (cup_ 130 m)',
#        'Ti (cup_ 130 m) QC', 'Direction (Vane_ 130 m)',
#        'Direction (Vane_ 130 m) QC',
#        ...
#        'Cup Equivalent Speed (sonic_15m) QC', 'Cup Equivalent Ti (sonic_15m)',
#        'Cup Equivalent Ti (sonic_15m) QC', 'Angle from horizontal (sonic_15m)',
#        'Angle from horizontal (sonic_15m) QC', 'Direction (sonic_15m)',
#        'Direction (sonic_15m) QC', '122m-38m wind shear exponent',
#        'Unnamed: 237', 'Unnamed: 238'],
#       dtype='object', length=239)

# %%
oldnames = df.columns[0:4]

# %%
oldnames
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3'], dtype='object')

# %%
newnames = pd.Series.tolist(df.iloc[1,[0,1,2,3]])

# %%
newnames
# Out:
# ['mm/dd/yyyy', 'Time', 'mm/dd/yyyy Time', 'UTC HOUR']

# %%
df.rename(columns=dict(zip(oldnames, newnames)), inplace = True)

# %%
df.columns[0:4]
# Out:
# Index(['mm/dd/yyyy', 'Time', 'mm/dd/yyyy Time', 'UTC HOUR'], dtype='object')

# %%
df.head()
# Out:
#    mm/dd/yyyy      Time    mm/dd/yyyy Time  UTC HOUR       Speed (cup_ 130 m)  \
# 0          --       NaN                NaN       NaN  Wind_Speed_Cup_130m.val
# 1  mm/dd/yyyy      Time    mm/dd/yyyy Time  UTC HOUR                      m/s
# 2      1/1/13  12:00 AM  1/1/2013 12:00 AM         0                 0.860275
# 3      1/1/13  12:10 AM  1/1/2013 12:10 AM         0                 0.730182
# 4      1/1/13  12:20 AM  1/1/2013 12:20 AM         0                 0.098562
#
#        Speed (cup_ 130 m) QC  Ti (cup_ 130 m)       Ti (cup_ 130 m) QC  \
# 0  Wind_Speed_Cup_130m.flags  Ti_Cup_130m.val        Ti_Cup_130m.flags
# 1    pass/flag/fail [1/0/-1]                %  pass/flag/fail [1/0/-1]
# 2                          0        13.335154                        0
# 3                          0        20.240985                        0
# 4                          0       154.370441                        0
#
# ...

# %%
extraHeader = df.iloc([0,1])

# %%
type(extraHeader)
# Out:
# pandas.core.indexing._iLocIndexer

# %%
df2 = df.drop([0,1])

# %%
df2.head()
# Out:
#   mm/dd/yyyy      Time    mm/dd/yyyy Time UTC HOUR Speed (cup_ 130 m)  \
# 2     1/1/13  12:00 AM  1/1/2013 12:00 AM        0           0.860275
# 3     1/1/13  12:10 AM  1/1/2013 12:10 AM        0           0.730182
# 4     1/1/13  12:20 AM  1/1/2013 12:20 AM        0           0.098562
# 5     1/1/13  12:30 AM  1/1/2013 12:30 AM        0           0.167043
# 6     1/1/13  12:40 AM  1/1/2013 12:40 AM        0           0.242969
#
#   Speed (cup_ 130 m) QC Ti (cup_ 130 m) Ti (cup_ 130 m) QC  \
# 2                     0       13.335154                  0
# 3                     0       20.240985                  0
# 4                     0      154.370441                  0
# 5                     0      116.755356                  0
# 6                     0         92.5277                  0
#
#   Direction (Vane_ 130 m) Direction (Vane_ 130 m) QC     ...       \
# 2                    -999                          0     ...
# ...

# %%
spd10m = df2['Speed (cup_ 10 m)']

# %%
type(spd10m)
# Out:
# pandas.core.series.Series

# %%
spd10m.values
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-143-eee32335bacd> in <module>()
# ----> 1 spd10m.values()
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
df2.describe(include='None')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-151-221f77ae00d9> in <module>()
# ----> 1 df2.describe(include='None')
#
# /Users/nhamilto/anaconda/lib/python3.6/site-packages/pandas/core/generic.py in describe(self, percentiles, include, exclude)
#    5808             data = self
#    5809         else:
# -> 5810             data = self.select_dtypes(include=include, exclude=exclude)
#    5811
#    5812         ldesc = [describe_1d(s) for _, s in data.iteritems()]
#
# /Users/nhamilto/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in select_dtypes(self, include, exclude)
#    2355         include, exclude = include or (), exclude or ()
#    2356         if not (is_list_like(include) and is_list_like(exclude)):
# -> 2357             raise TypeError('include and exclude must both be non-string'
#    2358                             ' sequences')
# ...

# %%
df2.head()
# Out:
#   mm/dd/yyyy      Time    mm/dd/yyyy Time UTC HOUR Speed (cup_ 130 m)  \
# 2     1/1/13  12:00 AM  1/1/2013 12:00 AM        0           0.860275
# 3     1/1/13  12:10 AM  1/1/2013 12:10 AM        0           0.730182
# 4     1/1/13  12:20 AM  1/1/2013 12:20 AM        0           0.098562
# 5     1/1/13  12:30 AM  1/1/2013 12:30 AM        0           0.167043
# 6     1/1/13  12:40 AM  1/1/2013 12:40 AM        0           0.242969
#
#   Speed (cup_ 130 m) QC Ti (cup_ 130 m) Ti (cup_ 130 m) QC  \
# 2                     0       13.335154                  0
# 3                     0       20.240985                  0
# 4                     0      154.370441                  0
# 5                     0      116.755356                  0
# 6                     0         92.5277                  0
#
#   Direction (Vane_ 130 m) Direction (Vane_ 130 m) QC     ...       \
# 2                    -999                          0     ...
# ...
